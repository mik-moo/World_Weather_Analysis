# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 749

# %%
# Starting URL for Weather Map API Call.
url = f"https://api.openweathermap.org/data/2.5/weather?&units=imperial&appid={weather_api_key}"

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
#     except:
    except Exception as e:
    # ... PRINT THE ERROR MESSAGE ... #
        print(e)
#         print("City not found. Skipping...")
        

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | katsuura
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | nikolskoye
# Processing Record 4 of Set 1 | vaini
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | jamestown
# Processing Record 7 of Set 1 | sechura
# Processing Record 8 of Set 1 | mareeba
# Processing Record 9 of Set 1 | pevek
# Processing Record 10 of Set 1 | saint-georges
# Processing Record 11 of Set 1 | bredasdorp
# Processing Record 12 of Set 1 | ketchikan
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | luderitz
# Processing Record 16 of Set 1 | zhezkazgan
# Processing Record 17 of Set 1 | vostok
# Processing Record 18 of Set 1 | lorengau
# Processing Record 19 of Set 1 | port elizabeth
# Processing Record 20 of Set 1 | huntsville
# Processing Record 21 of Set 1 | taolanaro
# 'coord'
# Processing Record 22 of Set 1 | kyren
# Processing Record 23 of Set 1 | avallon
# Processing Record 24 of Set 1 | avera
# Processing Record 25 of Set 1 | ancud
# Processing Record 26 of Set 1 | shirokiy
# Processing Record 27 of Set 1 | busselton
# Processing Record 28 of Set 1 | bluff
# Processing Record 29 of Set 1 | klyuchi
# Processing Record 30 of Set 1 | oltu
# Processing Record 31 of Set 1 | kodiak
# Processing Record 32 of Set 1 | mys shmidta
# 'coord'
# Processing Record 33 of Set 1 | saskylakh
# Processing Record 34 of Set 1 | opobo
# 'coord'
# Processing Record 35 of Set 1 | pisco
# Processing Record 36 of Set 1 | college
# Processing Record 37 of Set 1 | adrar
# Processing Record 38 of Set 1 | biltine
# Processing Record 39 of Set 1 | west point
# Processing Record 40 of Set 1 | platanos
# Processing Record 41 of Set 1 | cabo san lucas
# Processing Record 42 of Set 1 | vondrozo
# Processing Record 43 of Set 1 | rikitea
# Processing Record 44 of Set 1 | fujin
# Processing Record 45 of Set 1 | cape town
# Processing Record 46 of Set 1 | dingle
# Processing Record 47 of Set 1 | codrington
# Processing Record 48 of Set 1 | margate
# Processing Record 49 of Set 1 | new norfolk
# Processing Record 50 of Set 1 | tiksi
# Processing Record 1 of Set 2 | hobart
# Processing Record 2 of Set 2 | albany
# Processing Record 3 of Set 2 | ptuj
# Processing Record 4 of Set 2 | lebu
# Processing Record 5 of Set 2 | kapaa
# Processing Record 6 of Set 2 | porbandar
# Processing Record 7 of Set 2 | naryan-mar
# Processing Record 8 of Set 2 | lavrentiya
# Processing Record 9 of Set 2 | roald
# Processing Record 10 of Set 2 | butaritari
# Processing Record 11 of Set 2 | leningradskiy
# Processing Record 12 of Set 2 | mataura
# Processing Record 13 of Set 2 | vanimo
# Processing Record 14 of Set 2 | caucaia
# Processing Record 15 of Set 2 | chernyshkovskiy
# Processing Record 16 of Set 2 | castro
# Processing Record 17 of Set 2 | burica
# 'coord'
# Processing Record 18 of Set 2 | borovskoy
# Processing Record 19 of Set 2 | oksfjord
# Processing Record 20 of Set 2 | puerto ayora
# Processing Record 21 of Set 2 | nizhniy tsasuchey
# Processing Record 22 of Set 2 | khatanga
# Processing Record 23 of Set 2 | faya
# Processing Record 24 of Set 2 | bambous virieux
# Processing Record 25 of Set 2 | aflu
# 'coord'
# Processing Record 26 of Set 2 | barentsburg
# 'coord'
# Processing Record 27 of Set 2 | la ronge
# Processing Record 28 of Set 2 | san quintin
# Processing Record 29 of Set 2 | sedelnikovo
# 'coord'
# Processing Record 30 of Set 2 | micheweni
# Processing Record 31 of Set 2 | narsaq
# Processing Record 32 of Set 2 | victoria
# Processing Record 33 of Set 2 | carnarvon
# Processing Record 34 of Set 2 | mangan
# Processing Record 35 of Set 2 | congleton
# Processing Record 36 of Set 2 | flinders
# Processing Record 37 of Set 2 | yarkovo
# Processing Record 38 of Set 2 | khao wong
# Processing Record 39 of Set 2 | lazaro cardenas
# Processing Record 40 of Set 2 | bubaque
# Processing Record 41 of Set 2 | qaanaaq
# Processing Record 42 of Set 2 | ashland
# Processing Record 43 of Set 2 | garissa
# Processing Record 44 of Set 2 | wakkanai
# Processing Record 45 of Set 2 | mankono
# Processing Record 46 of Set 2 | hilo
# Processing Record 47 of Set 2 | gandiaye
# Processing Record 48 of Set 2 | edmundston
# Processing Record 49 of Set 2 | auki
# Processing Record 50 of Set 2 | avarua
# Processing Record 1 of Set 3 | tutoia
# Processing Record 2 of Set 3 | barinas
# Processing Record 3 of Set 3 | liwale
# Processing Record 4 of Set 3 | niono
# Processing Record 5 of Set 3 | agar
# Processing Record 6 of Set 3 | ribeira grande
# Processing Record 7 of Set 3 | tuktoyaktuk
# Processing Record 8 of Set 3 | los algarrobos
# Processing Record 9 of Set 3 | yellowknife
# Processing Record 10 of Set 3 | okhotsk
# Processing Record 11 of Set 3 | jacksonville
# Processing Record 12 of Set 3 | hasaki
# Processing Record 13 of Set 3 | gharo
# Processing Record 14 of Set 3 | loyga
# Processing Record 15 of Set 3 | port alfred
# Processing Record 16 of Set 3 | berlevag
# Processing Record 17 of Set 3 | umzimvubu
# 'coord'
# Processing Record 18 of Set 3 | east london
# Processing Record 19 of Set 3 | santa rosa
# Processing Record 20 of Set 3 | barrow
# Processing Record 21 of Set 3 | tomigusuku
# Processing Record 22 of Set 3 | mar del plata
# Processing Record 23 of Set 3 | bengkulu
# Processing Record 24 of Set 3 | contamana
# Processing Record 25 of Set 3 | kruisfontein
# Processing Record 26 of Set 3 | tagusao
# Processing Record 27 of Set 3 | mizdah
# Processing Record 28 of Set 3 | katherine
# Processing Record 29 of Set 3 | los llanos de aridane
# Processing Record 30 of Set 3 | amderma
# 'coord'
# Processing Record 31 of Set 3 | palabuhanratu
# 'coord'
# Processing Record 32 of Set 3 | maniitsoq
# Processing Record 33 of Set 3 | bronnoysund
# Processing Record 34 of Set 3 | vila franca do campo
# Processing Record 35 of Set 3 | barabai
# Processing Record 36 of Set 3 | kahului
# Processing Record 37 of Set 3 | peniche
# Processing Record 38 of Set 3 | bose
# Processing Record 39 of Set 3 | kavaratti
# Processing Record 40 of Set 3 | tahlequah
# Processing Record 41 of Set 3 | gemena
# Processing Record 42 of Set 3 | russell
# Processing Record 43 of Set 3 | cerro punta
# Processing Record 44 of Set 3 | attawapiskat
# 'coord'
# Processing Record 45 of Set 3 | iqaluit
# Processing Record 46 of Set 3 | kavieng
# Processing Record 47 of Set 3 | husavik
# Processing Record 48 of Set 3 | vaitupu
# 'coord'
# Processing Record 49 of Set 3 | levin
# Processing Record 50 of Set 3 | arraial do cabo
# Processing Record 1 of Set 4 | klaksvik
# Processing Record 2 of Set 4 | a
# 'coord'
# Processing Record 3 of Set 4 | navalmoral de la mata
# Processing Record 4 of Set 4 | fort nelson
# Processing Record 5 of Set 4 | caravelas
# Processing Record 6 of Set 4 | port-de-paix
# 'coord'
# Processing Record 7 of Set 4 | eyl
# Processing Record 8 of Set 4 | illoqqortoormiut
# 'coord'
# Processing Record 9 of Set 4 | guiyang
# Processing Record 10 of Set 4 | ilulissat
# Processing Record 11 of Set 4 | pojuca
# Processing Record 12 of Set 4 | simao
# Processing Record 13 of Set 4 | turukhansk
# Processing Record 14 of Set 4 | anadyr
# Processing Record 15 of Set 4 | salalah
# Processing Record 16 of Set 4 | ola
# Processing Record 17 of Set 4 | huaicheng
# Processing Record 18 of Set 4 | byron bay
# Processing Record 19 of Set 4 | birao
# Processing Record 20 of Set 4 | alofi
# Processing Record 21 of Set 4 | jalu
# Processing Record 22 of Set 4 | te anau
# Processing Record 23 of Set 4 | vestmannaeyjar
# Processing Record 24 of Set 4 | manokwari
# Processing Record 25 of Set 4 | sitka
# Processing Record 26 of Set 4 | yavatmal
# Processing Record 27 of Set 4 | tazovskiy
# Processing Record 28 of Set 4 | faanui
# Processing Record 29 of Set 4 | nanzhang
# Processing Record 30 of Set 4 | nouadhibou
# Processing Record 31 of Set 4 | iquique
# Processing Record 32 of Set 4 | sokolovo
# Processing Record 33 of Set 4 | sao filipe
# Processing Record 34 of Set 4 | saint george
# Processing Record 35 of Set 4 | camocim
# Processing Record 36 of Set 4 | saint-fabien
# 'coord'
# Processing Record 37 of Set 4 | campos
# Processing Record 38 of Set 4 | launceston
# Processing Record 39 of Set 4 | praxedis guerrero
# Processing Record 40 of Set 4 | ituni
# 'coord'
# Processing Record 41 of Set 4 | sayyan
# Processing Record 42 of Set 4 | mus
# Processing Record 43 of Set 4 | altay
# Processing Record 44 of Set 4 | guerrero negro
# Processing Record 45 of Set 4 | portland
# Processing Record 46 of Set 4 | egvekinot
# Processing Record 47 of Set 4 | pilar
# Processing Record 48 of Set 4 | clyde river
# Processing Record 49 of Set 4 | grants
# Processing Record 50 of Set 4 | sinnamary
# Processing Record 1 of Set 5 | puerto del rosario
# Processing Record 2 of Set 5 | vestmanna
# Processing Record 3 of Set 5 | bougouni
# Processing Record 4 of Set 5 | ostrovnoy
# Processing Record 5 of Set 5 | san patricio
# Processing Record 6 of Set 5 | kununurra
# Processing Record 7 of Set 5 | maracacume
# Processing Record 8 of Set 5 | lucapa
# Processing Record 9 of Set 5 | rundu
# Processing Record 10 of Set 5 | marcona
# 'coord'
# Processing Record 11 of Set 5 | samusu
# 'coord'
# Processing Record 12 of Set 5 | suntar
# Processing Record 13 of Set 5 | broome
# Processing Record 14 of Set 5 | kaitangata
# Processing Record 15 of Set 5 | kemijarvi
# Processing Record 16 of Set 5 | aklavik
# Processing Record 17 of Set 5 | axim
# Processing Record 18 of Set 5 | georgetown
# Processing Record 19 of Set 5 | fortuna
# Processing Record 20 of Set 5 | dikson
# Processing Record 21 of Set 5 | grand river south east
# 'coord'
# Processing Record 22 of Set 5 | zhanaozen
# Processing Record 23 of Set 5 | grand centre
# 'coord'
# Processing Record 24 of Set 5 | maceio
# Processing Record 25 of Set 5 | ahipara
# Processing Record 26 of Set 5 | norman wells
# Processing Record 27 of Set 5 | morant bay
# Processing Record 28 of Set 5 | lagoa
# Processing Record 29 of Set 5 | hithadhoo
# Processing Record 30 of Set 5 | bethel
# Processing Record 31 of Set 5 | port hardy
# Processing Record 32 of Set 5 | hualmay
# Processing Record 33 of Set 5 | safaqis
# 'coord'
# Processing Record 34 of Set 5 | severo-kurilsk
# Processing Record 35 of Set 5 | vila velha
# Processing Record 36 of Set 5 | souillac
# Processing Record 37 of Set 5 | hirara
# Processing Record 38 of Set 5 | tuatapere
# Processing Record 39 of Set 5 | ujfeherto
# Processing Record 40 of Set 5 | collie
# Processing Record 41 of Set 5 | hambantota
# Processing Record 42 of Set 5 | pakxan
# Processing Record 43 of Set 5 | airai
# Processing Record 44 of Set 5 | mogadishu
# Processing Record 45 of Set 5 | sahuaripa
# Processing Record 46 of Set 5 | arkhara
# Processing Record 47 of Set 5 | san cristobal
# Processing Record 48 of Set 5 | san jose
# Processing Record 49 of Set 5 | sorland
# Processing Record 50 of Set 5 | meyungs
# 'coord'
# Processing Record 1 of Set 6 | tawnat
# 'coord'
# Processing Record 2 of Set 6 | tessalit
# Processing Record 3 of Set 6 | ngukurr
# 'coord'
# Processing Record 4 of Set 6 | garowe
# Processing Record 5 of Set 6 | longyearbyen
# Processing Record 6 of Set 6 | bonthe
# Processing Record 7 of Set 6 | lompoc
# Processing Record 8 of Set 6 | chokurdakh
# Processing Record 9 of Set 6 | hailar
# Processing Record 10 of Set 6 | taunggyi
# Processing Record 11 of Set 6 | tasiilaq
# Processing Record 12 of Set 6 | palmares do sul
# Processing Record 13 of Set 6 | eau claire
# Processing Record 14 of Set 6 | belushya guba
# 'coord'
# Processing Record 15 of Set 6 | thai binh
# Processing Record 16 of Set 6 | zhigansk
# Processing Record 17 of Set 6 | blackfoot
# Processing Record 18 of Set 6 | filingue
# Processing Record 19 of Set 6 | waldshut-tiengen
# Processing Record 20 of Set 6 | shingu
# Processing Record 21 of Set 6 | tigzirt
# Processing Record 22 of Set 6 | hobyo
# Processing Record 23 of Set 6 | chicama
# Processing Record 24 of Set 6 | acapulco
# Processing Record 25 of Set 6 | dunedin
# Processing Record 26 of Set 6 | chama
# Processing Record 27 of Set 6 | mayumba
# Processing Record 28 of Set 6 | vadlapudi
# Processing Record 29 of Set 6 | port macquarie
# Processing Record 30 of Set 6 | qitaihe
# Processing Record 31 of Set 6 | chuy
# Processing Record 32 of Set 6 | jinka
# Processing Record 33 of Set 6 | ruatoria
# 'coord'
# Processing Record 34 of Set 6 | thompson
# Processing Record 35 of Set 6 | najran
# Processing Record 36 of Set 6 | albion
# Processing Record 37 of Set 6 | provideniya
# Processing Record 38 of Set 6 | taoudenni
# Processing Record 39 of Set 6 | charters towers
# Processing Record 40 of Set 6 | moreira sales
# Processing Record 41 of Set 6 | evensk
# Processing Record 42 of Set 6 | qui nhon
# Processing Record 43 of Set 6 | bela vista
# Processing Record 44 of Set 6 | saleaula
# 'coord'
# Processing Record 45 of Set 6 | gashua
# Processing Record 46 of Set 6 | tautira
# Processing Record 47 of Set 6 | ranot
# Processing Record 48 of Set 6 | paucartambo
# 'coord'
# Processing Record 49 of Set 6 | tura
# Processing Record 50 of Set 6 | rakke
# Processing Record 1 of Set 7 | miri
# Processing Record 2 of Set 7 | plettenberg bay
# Processing Record 3 of Set 7 | santa barbara
# Processing Record 4 of Set 7 | feni
# Processing Record 5 of Set 7 | enugu
# Processing Record 6 of Set 7 | nizhneyansk
# 'coord'
# Processing Record 7 of Set 7 | shurugwi
# Processing Record 8 of Set 7 | vieux-habitants
# Processing Record 9 of Set 7 | walvis bay
# Processing Record 10 of Set 7 | muros
# Processing Record 11 of Set 7 | seymchan
# Processing Record 12 of Set 7 | pimampiro
# Processing Record 13 of Set 7 | acajutla
# Processing Record 14 of Set 7 | harindanga
# Processing Record 15 of Set 7 | ahuimanu
# Processing Record 16 of Set 7 | thurso
# Processing Record 17 of Set 7 | oktyabrskoye
# Processing Record 18 of Set 7 | hofn
# Processing Record 19 of Set 7 | malindi
# Processing Record 20 of Set 7 | saint-philippe
# Processing Record 21 of Set 7 | coffs harbour
# Processing Record 22 of Set 7 | bhimunipatnam
# Processing Record 23 of Set 7 | kenora
# Processing Record 24 of Set 7 | idrinskoye
# Processing Record 25 of Set 7 | talnakh
# Processing Record 26 of Set 7 | gambo
# Processing Record 27 of Set 7 | entebbe
# Processing Record 28 of Set 7 | boulsa
# Processing Record 29 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 30 of Set 7 | washim
# Processing Record 31 of Set 7 | fukue
# Processing Record 32 of Set 7 | padang
# Processing Record 33 of Set 7 | vardo
# Processing Record 34 of Set 7 | flin flon
# Processing Record 35 of Set 7 | buala
# Processing Record 36 of Set 7 | port-gentil
# Processing Record 37 of Set 7 | chekmagush
# Processing Record 38 of Set 7 | phonhong
# Processing Record 39 of Set 7 | port lincoln
# Processing Record 40 of Set 7 | champerico
# Processing Record 41 of Set 7 | diu
# Processing Record 42 of Set 7 | vao
# Processing Record 43 of Set 7 | yibin
# Processing Record 44 of Set 7 | kargasok
# Processing Record 45 of Set 7 | bogorodskoye
# Processing Record 46 of Set 7 | haysville
# Processing Record 47 of Set 7 | manado
# Processing Record 48 of Set 7 | altamont
# Processing Record 49 of Set 7 | burgeo
# Processing Record 50 of Set 7 | xuddur
# Processing Record 1 of Set 8 | richards bay
# Processing Record 2 of Set 8 | kaseda
# Processing Record 3 of Set 8 | comodoro rivadavia
# Processing Record 4 of Set 8 | luanda
# Processing Record 5 of Set 8 | esperance
# Processing Record 6 of Set 8 | alice springs
# Processing Record 7 of Set 8 | lasa
# Processing Record 8 of Set 8 | cabinda
# Processing Record 9 of Set 8 | hay river
# Processing Record 10 of Set 8 | seda
# Processing Record 11 of Set 8 | svetlogorsk
# Processing Record 12 of Set 8 | tsogni
# Processing Record 13 of Set 8 | buon me thuot
# 'coord'
# Processing Record 14 of Set 8 | angatuba
# Processing Record 15 of Set 8 | victor harbor
# Processing Record 16 of Set 8 | rocha
# Processing Record 17 of Set 8 | esna
# Processing Record 18 of Set 8 | stephenville
# Processing Record 19 of Set 8 | half moon bay
# Processing Record 20 of Set 8 | bodden town
# Processing Record 21 of Set 8 | saraza
# Processing Record 22 of Set 8 | lakes entrance
# Processing Record 23 of Set 8 | rongcheng
# Processing Record 24 of Set 8 | ciudad bolivar
# Processing Record 25 of Set 8 | la palma
# Processing Record 26 of Set 8 | kushiro
# Processing Record 27 of Set 8 | bahia honda
# Processing Record 28 of Set 8 | sao felix do xingu
# Processing Record 29 of Set 8 | korla
# Processing Record 30 of Set 8 | springfield
# Processing Record 31 of Set 8 | benavente
# Processing Record 32 of Set 8 | puerto escondido
# Processing Record 33 of Set 8 | atagay
# Processing Record 34 of Set 8 | abu ghosh
# Processing Record 35 of Set 8 | palmer
# Processing Record 36 of Set 8 | nanortalik
# Processing Record 37 of Set 8 | ponta do sol
# Processing Record 38 of Set 8 | tsihombe
# 'coord'
# Processing Record 39 of Set 8 | kamenskoye
# 'coord'
# Processing Record 40 of Set 8 | kushima
# Processing Record 41 of Set 8 | wynyard
# Processing Record 42 of Set 8 | pangnirtung
# Processing Record 43 of Set 8 | brownfield
# Processing Record 44 of Set 8 | moura
# Processing Record 45 of Set 8 | goderich
# Processing Record 46 of Set 8 | hami
# Processing Record 47 of Set 8 | cap malheureux
# Processing Record 48 of Set 8 | cam pha
# 'coord'
# Processing Record 49 of Set 8 | barra da estiva
# Processing Record 50 of Set 8 | kaihua
# Processing Record 1 of Set 9 | kolokani
# Processing Record 2 of Set 9 | coquimbo
# Processing Record 3 of Set 9 | gulshat
# 'coord'
# Processing Record 4 of Set 9 | bada
# Processing Record 5 of Set 9 | mogok
# Processing Record 6 of Set 9 | tabiauea
# 'coord'
# Processing Record 7 of Set 9 | nhulunbuy
# Processing Record 8 of Set 9 | makakilo city
# Processing Record 9 of Set 9 | baghdad
# Processing Record 10 of Set 9 | tam ky
# Processing Record 11 of Set 9 | moron
# Processing Record 12 of Set 9 | deputatskiy
# Processing Record 13 of Set 9 | omboue
# Processing Record 14 of Set 9 | severobaykalsk
# Processing Record 15 of Set 9 | rudsar
# Processing Record 16 of Set 9 | coihaique
# Processing Record 17 of Set 9 | hyderabad
# Processing Record 18 of Set 9 | kudahuvadhoo
# Processing Record 19 of Set 9 | araouane
# Processing Record 20 of Set 9 | forchheim
# Processing Record 21 of Set 9 | derzhavinsk
# Processing Record 22 of Set 9 | bilma
# Processing Record 23 of Set 9 | northampton
# Processing Record 24 of Set 9 | nikolayevka
# Processing Record 25 of Set 9 | constitucion
# Processing Record 26 of Set 9 | juba
# Processing Record 27 of Set 9 | kazalinsk
# 'coord'
# Processing Record 28 of Set 9 | yatou
# Processing Record 29 of Set 9 | yulara
# Processing Record 30 of Set 9 | atar
# Processing Record 31 of Set 9 | asht
# 'coord'
# Processing Record 32 of Set 9 | gunjur
# Processing Record 33 of Set 9 | viransehir
# Processing Record 34 of Set 9 | havelock
# Processing Record 35 of Set 9 | nouakchott
# Processing Record 36 of Set 9 | pierre
# Processing Record 37 of Set 9 | ust-nera
# Processing Record 38 of Set 9 | honningsvag
# Processing Record 39 of Set 9 | fethiye
# Processing Record 40 of Set 9 | sisimiut
# Processing Record 41 of Set 9 | tiznit
# Processing Record 42 of Set 9 | buarcos
# Processing Record 43 of Set 9 | varhaug
# Processing Record 44 of Set 9 | banmo
# 'coord'
# Processing Record 45 of Set 9 | paris
# Processing Record 46 of Set 9 | marsh harbour
# Processing Record 47 of Set 9 | omsukchan
# Processing Record 48 of Set 9 | abu zabad
# Processing Record 49 of Set 9 | ulaanbaatar
# Processing Record 50 of Set 9 | chivacoa
# Processing Record 1 of Set 10 | tilichiki
# Processing Record 2 of Set 10 | ayagoz
# Processing Record 3 of Set 10 | tevriz
# Processing Record 4 of Set 10 | cidreira
# Processing Record 5 of Set 10 | mayo
# Processing Record 6 of Set 10 | kungurtug
# Processing Record 7 of Set 10 | jardin
# Processing Record 8 of Set 10 | praia da vitoria
# Processing Record 9 of Set 10 | komsomolskiy
# Processing Record 10 of Set 10 | marsa matruh
# Processing Record 11 of Set 10 | greenville
# Processing Record 12 of Set 10 | kenai
# Processing Record 13 of Set 10 | kita
# Processing Record 14 of Set 10 | san andres
# Processing Record 15 of Set 10 | boysun
# Processing Record 16 of Set 10 | daru
# Processing Record 17 of Set 10 | dinsor
# 'coord'
# Processing Record 18 of Set 10 | benito juarez
# Processing Record 19 of Set 10 | kutum
# Processing Record 20 of Set 10 | mandalgovi
# Processing Record 21 of Set 10 | scarborough
# Processing Record 22 of Set 10 | orlik
# Processing Record 23 of Set 10 | yaguajay
# Processing Record 24 of Set 10 | dandong
# Processing Record 25 of Set 10 | meadow lake
# Processing Record 26 of Set 10 | ontario
# Processing Record 27 of Set 10 | tres de maio
# Processing Record 28 of Set 10 | gonen
# Processing Record 29 of Set 10 | saint-francois
# Processing Record 30 of Set 10 | rio grande
# Processing Record 31 of Set 10 | umm durman
# 'coord'
# Processing Record 32 of Set 10 | rawson
# Processing Record 33 of Set 10 | mahebourg
# Processing Record 34 of Set 10 | bud
# Processing Record 35 of Set 10 | calama
# Processing Record 36 of Set 10 | chimbote
# Processing Record 37 of Set 10 | fort-shevchenko
# Processing Record 38 of Set 10 | beringovskiy
# Processing Record 39 of Set 10 | shelabolikha
# Processing Record 40 of Set 10 | villanueva de cordoba
# Processing Record 41 of Set 10 | akropong
# Processing Record 42 of Set 10 | kitama
# Processing Record 43 of Set 10 | fuyang
# Processing Record 44 of Set 10 | hornepayne
# Processing Record 45 of Set 10 | achisay
# 'coord'
# Processing Record 46 of Set 10 | wexford
# Processing Record 47 of Set 10 | jaramana
# 'coord'
# Processing Record 48 of Set 10 | sindor
# Processing Record 49 of Set 10 | geraldton
# Processing Record 50 of Set 10 | darapidap
# Processing Record 1 of Set 11 | matay
# Processing Record 2 of Set 11 | port hedland
# Processing Record 3 of Set 11 | traverse city
# Processing Record 4 of Set 11 | parkhill
# Processing Record 5 of Set 11 | northborough
# Processing Record 6 of Set 11 | sentyabrskiy
# 'coord'
# Processing Record 7 of Set 11 | kloulklubed
# Processing Record 8 of Set 11 | miranda
# Processing Record 9 of Set 11 | brae
# Processing Record 10 of Set 11 | hokitika
# Processing Record 11 of Set 11 | san policarpo
# Processing Record 12 of Set 11 | grindavik
# Processing Record 13 of Set 11 | davila
# Processing Record 14 of Set 11 | rawannawi
# 'coord'
# Processing Record 15 of Set 11 | balabag
# Processing Record 16 of Set 11 | cap-aux-meules
# Processing Record 17 of Set 11 | wagar
# Processing Record 18 of Set 11 | umea
# Processing Record 19 of Set 11 | opuwo
# Processing Record 20 of Set 11 | iskateley
# Processing Record 21 of Set 11 | toliary
# 'coord'
# Processing Record 22 of Set 11 | grand gaube
# Processing Record 23 of Set 11 | yar-sale
# Processing Record 24 of Set 11 | high prairie
# Processing Record 25 of Set 11 | port blair
# Processing Record 26 of Set 11 | mehamn
# Processing Record 27 of Set 11 | port shepstone
# Processing Record 28 of Set 11 | pointe michel
# Processing Record 29 of Set 11 | romitan
# Processing Record 30 of Set 11 | sorvag
# 'coord'
# Processing Record 31 of Set 11 | dalhousie
# Processing Record 32 of Set 11 | chihuahua
# Processing Record 33 of Set 11 | bundaberg
# Processing Record 34 of Set 11 | impfondo
# Processing Record 35 of Set 11 | tecpan
# Processing Record 36 of Set 11 | kargil
# Processing Record 37 of Set 11 | honiara
# Processing Record 38 of Set 11 | utete
# Processing Record 39 of Set 11 | jishou
# Processing Record 40 of Set 11 | ngunguru
# Processing Record 41 of Set 11 | gao
# Processing Record 42 of Set 11 | payakumbuh
# Processing Record 43 of Set 11 | taybad
# Processing Record 44 of Set 11 | elat
# Processing Record 45 of Set 11 | derbent
# Processing Record 46 of Set 11 | torbay
# Processing Record 47 of Set 11 | utiroa
# 'coord'
# Processing Record 48 of Set 11 | laguna
# Processing Record 49 of Set 11 | cordoba
# Processing Record 50 of Set 11 | saint-pierre
# Processing Record 1 of Set 12 | ratholo
# Processing Record 2 of Set 12 | ayan
# Processing Record 3 of Set 12 | manggar
# Processing Record 4 of Set 12 | viedma
# Processing Record 5 of Set 12 | foxton
# Processing Record 6 of Set 12 | itapage
# Processing Record 7 of Set 12 | mentok
# 'coord'
# Processing Record 8 of Set 12 | nieuw amsterdam
# Processing Record 9 of Set 12 | bradford
# Processing Record 10 of Set 12 | eureka
# Processing Record 11 of Set 12 | aldan
# Processing Record 12 of Set 12 | nkongsamba
# Processing Record 13 of Set 12 | weligama
# Processing Record 14 of Set 12 | mount isa
# Processing Record 15 of Set 12 | waingapu
# Processing Record 16 of Set 12 | praia
# Processing Record 17 of Set 12 | ossora
# Processing Record 18 of Set 12 | mabopane
# Processing Record 19 of Set 12 | ucluelet
# Processing Record 20 of Set 12 | ust-kamchatsk
# 'coord'
# Processing Record 21 of Set 12 | upernavik
# Processing Record 22 of Set 12 | tarudant
# 'coord'
# Processing Record 23 of Set 12 | marfino
# Processing Record 24 of Set 12 | tibu
# Processing Record 25 of Set 12 | hervey bay
# Processing Record 26 of Set 12 | ornskoldsvik
# Processing Record 27 of Set 12 | saint-augustin
# Processing Record 28 of Set 12 | eldikan
# 'coord'
# Processing Record 29 of Set 12 | shakhtinsk
# Processing Record 30 of Set 12 | dibombari
# Processing Record 31 of Set 12 | matsanga
# 'coord'
# Processing Record 32 of Set 12 | kulhudhuffushi
# Processing Record 33 of Set 12 | san javier
# Processing Record 34 of Set 12 | cherskiy
# Processing Record 35 of Set 12 | tawkar
# 'coord'
# Processing Record 36 of Set 12 | muisne
# Processing Record 37 of Set 12 | yuli
# Processing Record 38 of Set 12 | goundam
# Processing Record 39 of Set 12 | malabo
# Processing Record 40 of Set 12 | lumphat
# Processing Record 41 of Set 12 | uray
# Processing Record 42 of Set 12 | salamiyah
# Processing Record 43 of Set 12 | west plains
# Processing Record 44 of Set 12 | hereford
# Processing Record 45 of Set 12 | lata
# Processing Record 46 of Set 12 | raton
# Processing Record 47 of Set 12 | falealupo
# 'coord'
# Processing Record 48 of Set 12 | ulladulla
# Processing Record 49 of Set 12 | kasukabe
# Processing Record 50 of Set 12 | caxito
# Processing Record 1 of Set 13 | aloleng
# Processing Record 2 of Set 13 | artyom
# Processing Record 3 of Set 13 | kautokeino
# Processing Record 4 of Set 13 | santa marta
# Processing Record 5 of Set 13 | longonjo
# Processing Record 6 of Set 13 | roma
# Processing Record 7 of Set 13 | ivanava
# Processing Record 8 of Set 13 | sao joao da barra
# Processing Record 9 of Set 13 | saint-joseph
# Processing Record 10 of Set 13 | gayny
# Processing Record 11 of Set 13 | pacific grove
# Processing Record 12 of Set 13 | fairbanks
# Processing Record 13 of Set 13 | ust-tsilma
# Processing Record 14 of Set 13 | el rosario
# Processing Record 15 of Set 13 | tambovka
# Processing Record 16 of Set 13 | caraballeda
# Processing Record 17 of Set 13 | igarka
# Processing Record 18 of Set 13 | maniwaki
# Processing Record 19 of Set 13 | tecoanapa
# Processing Record 20 of Set 13 | hargeysa
# Processing Record 21 of Set 13 | galesong
# Processing Record 22 of Set 13 | batetskiy
# Processing Record 23 of Set 13 | kolpashevo
# Processing Record 24 of Set 13 | sangar
# Processing Record 25 of Set 13 | lugovoy
# Processing Record 26 of Set 13 | san borja
# Processing Record 27 of Set 13 | kondinskoye
# Processing Record 28 of Set 13 | yarmouth
# Processing Record 29 of Set 13 | weihai
# Processing Record 30 of Set 13 | mahibadhoo
# Processing Record 31 of Set 13 | mirante do paranapanema
# Processing Record 32 of Set 13 | basco
# Processing Record 33 of Set 13 | redwater
# Processing Record 34 of Set 13 | qaqortoq
# Processing Record 35 of Set 13 | phu khieo
# 'coord'
# Processing Record 36 of Set 13 | sarangani
# Processing Record 37 of Set 13 | borlange
# 'coord'
# Processing Record 38 of Set 13 | kytlym
# 'coord'
# Processing Record 39 of Set 13 | ocampo
# Processing Record 40 of Set 13 | tarko-sale
# Processing Record 41 of Set 13 | santa maria
# Processing Record 42 of Set 13 | tostamaa
# 'coord'
# Processing Record 43 of Set 13 | saurimo
# Processing Record 44 of Set 13 | moree
# Processing Record 45 of Set 13 | zeya
# Processing Record 46 of Set 13 | port hawkesbury
# Processing Record 47 of Set 13 | cabedelo
# Processing Record 48 of Set 13 | yashalta
# Processing Record 49 of Set 13 | mantua
# Processing Record 50 of Set 13 | tshane
# Processing Record 1 of Set 14 | phalaborwa
# Processing Record 2 of Set 14 | nadym
# Processing Record 3 of Set 14 | boissevain
# Processing Record 4 of Set 14 | tupik
# Processing Record 5 of Set 14 | poum
# Processing Record 6 of Set 14 | kieta
# Processing Record 7 of Set 14 | bathsheba
# Processing Record 8 of Set 14 | isangel
# Processing Record 9 of Set 14 | jaguaruna
# Processing Record 10 of Set 14 | necochea
# Processing Record 11 of Set 14 | barroualie
# 'coord'
# Processing Record 12 of Set 14 | inuvik
# Processing Record 13 of Set 14 | kuala pilah
# Processing Record 14 of Set 14 | labuhan
# Processing Record 15 of Set 14 | starkville
# Processing Record 16 of Set 14 | agadez
# Processing Record 17 of Set 14 | kabinda
# Processing Record 18 of Set 14 | dhidhdhoo
# Processing Record 19 of Set 14 | mazatlan
# Processing Record 20 of Set 14 | ursulo galvan
# Processing Record 21 of Set 14 | moose factory
# Processing Record 22 of Set 14 | yashkul
# Processing Record 23 of Set 14 | sobolevo
# Processing Record 24 of Set 14 | porto novo
# Processing Record 25 of Set 14 | umm bab
# Processing Record 26 of Set 14 | aksu
# Processing Record 27 of Set 14 | finnsnes
# Processing Record 28 of Set 14 | tomatlan
# Processing Record 29 of Set 14 | ust-kuyga
# Processing Record 30 of Set 14 | smithers
# Processing Record 31 of Set 14 | la seyne-sur-mer
# Processing Record 32 of Set 14 | batesville
# Processing Record 33 of Set 14 | shelburne
# Processing Record 34 of Set 14 | pundaguitan
# Processing Record 35 of Set 14 | turtkul
# 'coord'
# Processing Record 36 of Set 14 | high level
# Processing Record 37 of Set 14 | sur
# Processing Record 38 of Set 14 | orotukan
# Processing Record 39 of Set 14 | anloga
# Processing Record 40 of Set 14 | manicore
# Processing Record 41 of Set 14 | labutta
# 'coord'
# Processing Record 42 of Set 14 | gorontalo
# Processing Record 43 of Set 14 | blagoyevo
# Processing Record 44 of Set 14 | pucallpa
# Processing Record 45 of Set 14 | sola
# Processing Record 46 of Set 14 | halifax
# Processing Record 47 of Set 14 | tucurui
# Processing Record 48 of Set 14 | banjar
# Processing Record 49 of Set 14 | hadrut
# Processing Record 50 of Set 14 | zarechnyy
# Processing Record 1 of Set 15 | blythe
# Processing Record 2 of Set 15 | bata
# Processing Record 3 of Set 15 | ostroh
# Processing Record 4 of Set 15 | camacha
# Processing Record 5 of Set 15 | namibe
# Processing Record 6 of Set 15 | sonoita
# Processing Record 7 of Set 15 | tangkak
# Processing Record 8 of Set 15 | ginda
# Processing Record 9 of Set 15 | kiunga
# Processing Record 10 of Set 15 | chikwawa
# Processing Record 11 of Set 15 | linhares
# Processing Record 12 of Set 15 | mirina
# 'coord'
# Processing Record 13 of Set 15 | tiarei
# Processing Record 14 of Set 15 | santa cruz de tenerife
# Processing Record 15 of Set 15 | kalemie
# Processing Record 16 of Set 15 | gondar
# Processing Record 17 of Set 15 | sakaiminato
# Processing Record 18 of Set 15 | swan river
# Processing Record 19 of Set 15 | thunder bay
# Processing Record 20 of Set 15 | touros
# Processing Record 21 of Set 15 | juneau
# Processing Record 22 of Set 15 | bom jesus
# Processing Record 23 of Set 15 | wukari
# Processing Record 24 of Set 15 | kuche
# 'coord'
# Processing Record 25 of Set 15 | muncar
# Processing Record 26 of Set 15 | milkovo
# Processing Record 27 of Set 15 | inhambane
# Processing Record 28 of Set 15 | buariki
# 'coord'
# Processing Record 29 of Set 15 | zlatoustovsk
# 'coord'
# Processing Record 30 of Set 15 | voznesenye
# Processing Record 31 of Set 15 | lolua
# 'coord'
# Processing Record 32 of Set 15 | znamenskoye
# Processing Record 33 of Set 15 | prainha
# Processing Record 34 of Set 15 | puurmani
# Processing Record 35 of Set 15 | ukiah
# Processing Record 36 of Set 15 | skelmersdale
# Processing Record 37 of Set 15 | sao francisco
# Processing Record 38 of Set 15 | dzilam gonzalez
# Processing Record 39 of Set 15 | cheuskiny
# 'coord'
# Processing Record 40 of Set 15 | burnie
# Processing Record 41 of Set 15 | oussouye
# Processing Record 42 of Set 15 | coahuayana
# Processing Record 43 of Set 15 | taicheng
# Processing Record 44 of Set 15 | paro
# Processing Record 45 of Set 15 | nishihara
# Processing Record 46 of Set 15 | beidao
# Processing Record 47 of Set 15 | da nang
# Processing Record 48 of Set 15 | nivala
# Processing Record 49 of Set 15 | kaduqli
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 681

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Katsuura      JP  35.1333  140.3000     72.84        90         100
# 1        Ushuaia      AR -54.8000  -68.3000     29.86        86          75
# 2     Nikolskoye      RU  59.7035   30.7861     53.49        86          99
# 3          Vaini      TO -21.2000 -175.2000     78.96        89          75
# 4   Punta Arenas      CL -53.1500  -70.9167     35.71        60          75
# 5      Jamestown      US  42.0970  -79.2353     73.71        72           1
# 6        Sechura      PE  -5.5569  -80.8222     71.64        57          43
# 7        Mareeba      AU -17.0000  145.4333     68.72        92          31
# 8          Pevek      RU  69.7008  170.3133     36.07        77         100
# 9  Saint-Georges      GD  12.0564  -61.7485     83.88        70          20
#
#    Wind Speed Current Description
# 0       10.42       moderate rain
# 1       20.71          light snow
# 2        5.06     overcast clouds
# 3        8.05       broken clouds
# 4       13.80       broken clouds
# 5       14.74           clear sky
# 6       15.93    scattered clouds
# 7        2.66    scattered clouds
# 8        4.74     overcast clouds
# 9       21.85          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_Name")
